# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# %%
philippine_all = pd.read_excel("./data/philippine/philippine_all.xlsx")
philippine_age = pd.read_csv("./data/philippine/philippine_age.csv", thousands = ',')
philippine_gender = pd.read_csv("./data/philippine/philippine_gender.csv")
philippine_visit = pd.read_csv("./data/philippine/philippine_visit.csv")
philippine_activity = pd.read_csv("./data/philippine/philippine_activity.csv")

# %%
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
plt.figure(figsize=(10,10))
x = np.arange(12)
plt.title("월별 한국 관광객 수 (필리핀)")
plt.bar(x, philippine_all["계"].values.tolist()[:12])
plt.xticks(x, philippine_all["월"].values.tolist()[:12])
plt.show()
# Out:
# [30473, 29294, 38701, 66525, 50569, 40748, 29074, 41817, 36252, 55394, 41739, 43281]

# %%
# print(philippine_age)
print(philippine_age)
ageData = []

ageData.append(philippine_age["20세이하_계"].values.tolist()[0])
ageData.append(philippine_age["20대_계"].values.tolist()[0])
ageData.append(philippine_age["30대_계"].values.tolist()[0])
ageData.append(philippine_age["40대_계"].values.tolist()[0])
ageData.append(philippine_age["50대_계"].values.tolist()[0])
ageData.append(philippine_age["60대_계"].values.tolist()[0])
print(ageData)

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rc('axes', titlesize=20)
plt.figure(figsize=(8,8))
ratio = ageData
labels = ['20세 이하', '20대', '30대', '40대', '50대', '60대']

wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.title("방한 관광객 연령 비율 (필리핀)")
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False,  wedgeprops=wedgeprops)
plt.show()
# Out:
#    20세이하_계  20세이하_전년동기  20세이하_증감률  20대_계  20대_전년동기  20대_증감률  30대_계  30대_전년동기  \
# 0    36778       34466       6.71  80160     76508     4.77  80592     73611
#
#    30대_증감률  40대_계  40대_전년동기  40대_증감률  50대_계  50대_전년동기  50대_증감률  60대_계  \
# 0     9.48  56394     50856    10.89  36517     33551     8.84  22323
#
#    60대_전년동기  60대_증감률
# 0     18802    18.73
# [36778, 80160, 80592, 56394, 36517, 22323]

# %%
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rc('axes', titlesize=20)
plt.figure(figsize=(8,8))
ratio = [151617, 161147]
labels = ['남성', '여성']

wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

plt.title("방한 관광객 남여 비율 (필리핀)")
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False,  wedgeprops=wedgeprops)
plt.show()

# %%
plt.figure(figsize=(10,10))
length = len(philippine_visit)
x = np.arange(length)
plt.title("방한 관광객 방문 지역 (필리핀)")
plt.bar(x, philippine_visit["2019"].values.tolist())
plt.xticks(x, philippine_visit["방문지역"].values.tolist())
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.barh(philippine_activity["한국방문 주요활동"].values.tolist(), philippine_activity["2019"].values.tolist())
plt.show()
# Out:
#                       한국방문 주요활동   2019
# 0   K-POP/한류스타관련공연장및드라마/영화촬영지방문  24.68
# 1                    고궁/역사유적지방문  78.81
# 2                            기타   0.90
# 3                     박물관,전시관방문  39.98
# 4                       뷰티/의료관광   9.43
# 5                            쇼핑  97.31
# 6                   스포츠/레저관람및참가   5.45
# 7                     시찰(산업시설등)   0.53
# 8                         식도락관광  58.12
# 9          업무수행(회의,학술대회,박람회등참여)  12.51
# 10                     연수,교육,연구   4.34
# 11                        유흥/오락  31.42
# 12                       자연경관감상  77.29
# 13    전통문화체험(한복체험,태권도,한국음식만들기등)  47.61
